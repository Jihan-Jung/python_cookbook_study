# %% [markdown]
# # 발표 소단원 리스트

# %% [markdown]
# 1-1,1-5,1-9,

# %% [markdown]
# # 전체 요약자료

# %% [markdown]
# - 급하면 최소한 이거라도 보고 오시라고!!
# - 전체 내용에 대한 문항별 요약도 좋고, 자기 나름대로의 요약도 좋습니다!!
# -

# %% [markdown]
# # 문항별 자료
# - 좀 더 자세한 내용 요약
# - 작성한 코드

# %% [markdown]
# ### 1-1) 제목
# - 내용 요약

# %%
### 코드 작성

# %% [markdown]
# ##### 보충 설명 (코멘트) 만약 있다면!!

# %% [markdown]
# ### 1-5) 제목
# - 내용 요약

# %%
### 코드 작성
